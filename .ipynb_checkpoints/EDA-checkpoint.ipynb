# %% [markdown]
# # Analysis of Foreign Visitor Influx: Patterns and Accommodation Preferences between 2023 and 2024

# %% [markdown]
# ## Context

# %% [markdown]
# This project employs a dataset sourced from the Central Statistics Office webpage, which includes data on the frequency of overnight trips, duration of stay, and average length of stay by international visitors across diverse lodging categories from January 2023 to August 2024.

# %% [markdown]
# ## Objective

# %% [markdown]
# This study aims to analyse and predict the average duration of international tourists' stays across various accommodation types utilising different machine learning techniques, while also identifying patterns and trends in accommodation preferences among foreign visitors from 2023 to 2024.

# %% [markdown]
# ## Problem statement

# %% [markdown]
# Predicting the average length of stay for foreign visitors across various accommodation types presents difficulties for the tourism sector due to fluctuating visitor behaviors and preferences. This study examines this issue by applying machine learning techniques to the analysis of historical data gathered over a 32-month period to forecast typical stay durations, offering insights that help improve planning and resource allocation in the business.

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# The Exploratory Data Analysis (EDA) involves summarizing the main characteristics of the dataset using statistical and visualization techniques.

# %% [markdown]
# ### Exploring the dataset

# %%
#importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
from scipy.stats import shapiro

#importing fuctions from a ipynb
# %run utilss.ipynb

#To read the file downloaded from the CSO.ie database
df = pd.read_csv('cso_data.csv', index_col=False)

# %%
#To get all the information realted to the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Statistic Label          600 non-null    object
#  1   Month                    600 non-null    object
#  2   Main Accommodation Type  600 non-null    object
#  3   UNIT                     600 non-null    object
#  4   VALUE                    600 non-null    float64
# dtypes: float64(1), object(4)
# memory usage: 23.6+ KB

# %%
#Shows the 5 first rows from the dataset
df.head()
# Out:
#                                  Statistic Label         Month  \
# 0  Number of Overnight Trips by Foreign Visitors  2023 January
# 1  Number of Overnight Trips by Foreign Visitors  2023 January
# 2  Number of Overnight Trips by Foreign Visitors  2023 January
# 3  Number of Overnight Trips by Foreign Visitors  2023 January
# 4  Number of Overnight Trips by Foreign Visitors  2023 January
#
#                       Main Accommodation Type      UNIT  VALUE
# 0                     Hotel/conference centre  Thousand  121.0
# 1                 Guest house/bed & breakfast  Thousand    8.5
# 2              Friends/relatives/own property  Thousand  243.4
# 3                  Self catering/rented house  Thousand   13.8
# 4  Other private tourism accommodation n.e.c.  Thousand   13.4

# %%
#To drop the feature Statistic Label
df = df.drop(columns=['Statistic Label'])

# %% [markdown]
# ### Reorganazing the dataset
#
# Reorganizing the dataset by creating new columns and assigning values from the existing `VALUE` column into these new features.

# %%
#Creates 5 new columns and asigned values from VALUE into the new features 
df['Number of Overnight Trips by Foreign Visitors (Thousand)'] = pd.Series(df['VALUE'].iloc[0:120].reset_index(drop=True))
df['Percentage of Overnight Trips by Foreign Visitors (%)'] = pd.Series(df['VALUE'].iloc[120:240].reset_index(drop=True))
df['Number of Nights by Foreign Visitors (Thousand)'] = pd.Series(df['VALUE'].iloc[240:360].reset_index(drop=True))
df['Percentage of Nights by Foreign Visitors (%)'] = pd.Series(df['VALUE'].iloc[360:480].reset_index(drop=True))
df['Average Length of Stay of Foreign Visitors (Nights per trip)'] = pd.Series(df['VALUE'].iloc[480:600].reset_index(drop=True))

# %%
df.head(120)
# Out:
#             Month                     Main Accommodation Type      UNIT  \
# 0    2023 January                     Hotel/conference centre  Thousand
# 1    2023 January                 Guest house/bed & breakfast  Thousand
# 2    2023 January              Friends/relatives/own property  Thousand
# 3    2023 January                  Self catering/rented house  Thousand
# 4    2023 January  Other private tourism accommodation n.e.c.  Thousand
# ..            ...                                         ...       ...
# 115   2024 August                 Guest house/bed & breakfast  Thousand
# 116   2024 August              Friends/relatives/own property  Thousand
# 117   2024 August                  Self catering/rented house  Thousand
# 118   2024 August  Other private tourism accommodation n.e.c.  Thousand
# 119   2024 August                  All types of accommodation  Thousand
#
#      VALUE  Number of Overnight Trips by Foreign Visitors (Thousand)  \
# 0    121.0                                              121.0
# 1      8.5                                                8.5
# 2    243.4                                              243.4
# 3     13.8                                               13.8
# 4     13.4                                               13.4
# ..     ...                                                ...
# 115   62.9                                               62.9
# 116  290.9                                              290.9
# 117   43.3                                               43.3
# 118   68.0                                               68.0
# 119  763.6                                              763.6
#
#      Percentage of Overnight Trips by Foreign Visitors (%)  \
# 0                                                 30.3
# 1                                                  2.1
# 2                                                 60.8
# 3                                                  3.4
# 4                                                  3.3
# ..                                                 ...
# 115                                                8.2
# 116                                               38.1
# 117                                                5.7
# 118                                                8.9
# 119                                              100.0
#
#      Number of Nights by Foreign Visitors (Thousand)  \
# 0                                              441.9
# 1                                               55.9
# 2                                             2701.9
# 3                                              154.8
# 4                                              341.6
# ..                                               ...
# 115                                            559.3
# 116                                           2958.5
# 117                                            483.7
# 118                                            920.8
# 119                                           6666.2
#
#      Percentage of Nights by Foreign Visitors (%)  \
# 0                                            12.0
# 1                                             1.5
# 2                                            73.1
# 3                                             4.2
# 4                                             9.2
# ..                                            ...
# 115                                           8.4
# 116                                          44.4
# 117                                           7.3
# 118                                          13.8
# 119                                         100.0
#
#      Average Length of Stay of Foreign Visitors (Nights per trip)
# 0                                                  3.7
# 1                                                  6.6
# 2                                                 11.1
# 3                                                 11.2
# 4                                                 25.5
# ..                                                 ...
# 115                                                8.9
# 116                                               10.2
# 117                                               11.2
# 118                                               13.5
# 119                                                8.7
#
# [120 rows x 9 columns]

# %%
#To drop features VALUE and UNIT
df = df.drop(columns=['VALUE', 'UNIT'])
#To drop all the observations after index 120
df = df.drop(df.index[120:])

# %%
df.head(125)
# Out:
#             Month                     Main Accommodation Type  \
# 0    2023 January                     Hotel/conference centre
# 1    2023 January                 Guest house/bed & breakfast
# 2    2023 January              Friends/relatives/own property
# 3    2023 January                  Self catering/rented house
# 4    2023 January  Other private tourism accommodation n.e.c.
# ..            ...                                         ...
# 115   2024 August                 Guest house/bed & breakfast
# 116   2024 August              Friends/relatives/own property
# 117   2024 August                  Self catering/rented house
# 118   2024 August  Other private tourism accommodation n.e.c.
# 119   2024 August                  All types of accommodation
#
#      Number of Overnight Trips by Foreign Visitors (Thousand)  \
# 0                                                121.0
# 1                                                  8.5
# 2                                                243.4
# 3                                                 13.8
# 4                                                 13.4
# ..                                                 ...
# 115                                               62.9
# 116                                              290.9
# 117                                               43.3
# 118                                               68.0
# 119                                              763.6
#
#      Percentage of Overnight Trips by Foreign Visitors (%)  \
# 0                                                 30.3
# 1                                                  2.1
# 2                                                 60.8
# 3                                                  3.4
# 4                                                  3.3
# ..                                                 ...
# 115                                                8.2
# 116                                               38.1
# 117                                                5.7
# 118                                                8.9
# 119                                              100.0
#
#      Number of Nights by Foreign Visitors (Thousand)  \
# 0                                              441.9
# 1                                               55.9
# 2                                             2701.9
# 3                                              154.8
# 4                                              341.6
# ..                                               ...
# 115                                            559.3
# 116                                           2958.5
# 117                                            483.7
# 118                                            920.8
# 119                                           6666.2
#
#      Percentage of Nights by Foreign Visitors (%)  \
# 0                                            12.0
# 1                                             1.5
# 2                                            73.1
# 3                                             4.2
# 4                                             9.2
# ..                                            ...
# 115                                           8.4
# 116                                          44.4
# 117                                           7.3
# 118                                          13.8
# 119                                         100.0
#
#      Average Length of Stay of Foreign Visitors (Nights per trip)
# 0                                                  3.7
# 1                                                  6.6
# 2                                                 11.1
# 3                                                 11.2
# 4                                                 25.5
# ..                                                 ...
# 115                                                8.9
# 116                                               10.2
# 117                                               11.2
# 118                                               13.5
# 119                                                8.7
#
# [120 rows x 7 columns]

# %%
#to split the feature "Month" into "Month" and "Year"
df[['Year', 'Month']] = df['Month'].str.split(' ', expand=True)

#To change Year's datatype  
df['Year'] = pd.to_datetime(df['Year'], format='%Y')
df['Year'] = df['Year'].dt.year

#To change month's datatype
df['Month'] = pd.to_datetime(df['Month'], format='%B')
df['Month'] = df['Month'].dt.month

# %%
df.head(6)
# Out:
#    Month                     Main Accommodation Type  \
# 0      1                     Hotel/conference centre
# 1      1                 Guest house/bed & breakfast
# 2      1              Friends/relatives/own property
# 3      1                  Self catering/rented house
# 4      1  Other private tourism accommodation n.e.c.
# 5      1                  All types of accommodation
#
#    Number of Overnight Trips by Foreign Visitors (Thousand)  \
# 0                                              121.0
# 1                                                8.5
# 2                                              243.4
# 3                                               13.8
# 4                                               13.4
# 5                                              400.0
#
#    Percentage of Overnight Trips by Foreign Visitors (%)  \
# 0                                               30.3
# 1                                                2.1
# 2                                               60.8
# 3                                                3.4
# 4                                                3.3
# 5                                              100.0
#
#    Number of Nights by Foreign Visitors (Thousand)  \
# 0                                            441.9
# 1                                             55.9
# 2                                           2701.9
# 3                                            154.8
# 4                                            341.6
# 5                                           3696.2
#
#    Percentage of Nights by Foreign Visitors (%)  \
# 0                                          12.0
# 1                                           1.5
# 2                                          73.1
# 3                                           4.2
# 4                                           9.2
# 5                                         100.0
#
#    Average Length of Stay of Foreign Visitors (Nights per trip)  Year
# 0                                                3.7             2023
# 1                                                6.6             2023
# 2                                               11.1             2023
# 3                                               11.2             2023
# 4                                               25.5             2023
# 5                                                9.2             2023

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 8 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Month                                                         120 non-null    int32
#  1   Main Accommodation Type                                       120 non-null    object
#  2   Number of Overnight Trips by Foreign Visitors (Thousand)      120 non-null    float64
#  3   Percentage of Overnight Trips by Foreign Visitors (%)         120 non-null    float64
#  4   Number of Nights by Foreign Visitors (Thousand)               120 non-null    float64
#  5   Percentage of Nights by Foreign Visitors (%)                  120 non-null    float64
#  6   Average Length of Stay of Foreign Visitors (Nights per trip)  120 non-null    float64
#  7   Year                                                          120 non-null    int32
# dtypes: float64(5), int32(2), object(1)
# memory usage: 6.7+ KB

# %%
df.describe()
# Out:
#             Month  Number of Overnight Trips by Foreign Visitors (Thousand)  \
# count  120.000000                                         120.000000
# mean     5.700000                                         182.068333
# std      3.208707                                         194.450136
# min      1.000000                                           7.100000
# 25%      3.000000                                          26.850000
# 50%      5.500000                                          95.900000
# 75%      8.000000                                         266.700000
# max     12.000000                                         763.600000
#
#        Percentage of Overnight Trips by Foreign Visitors (%)  \
# count                                         120.000000
# mean                                           33.334167
# std                                            34.420437
# min                                             2.100000
# 25%                                             5.075000
# 50%                                            20.550000
# 75%                                            46.125000
# max                                           100.000000
#
#        Number of Nights by Foreign Visitors (Thousand)  \
# count                                        120.00000
# mean                                        1425.00000
# std                                         1540.59099
# min                                           45.30000
# 25%                                          333.37500
# 50%                                          811.20000
# 75%                                         1785.32500
# max                                         7337.70000
#
#        Percentage of Nights by Foreign Visitors (%)  \
# count                                    120.000000
# mean                                      33.332500
# std                                       33.579368
# min                                        1.500000
# 25%                                        7.850000
# 50%                                       19.650000
# 75%                                       44.600000
# max                                      100.000000
#
#        Average Length of Stay of Foreign Visitors (Nights per trip)  \
# count                                          120.00000
# mean                                            10.04750
# std                                              6.67257
# min                                              3.30000
# 25%                                              6.37500
# 50%                                              8.15000
# 75%                                             11.60000
# max                                             56.00000
#
#               Year
# count   120.000000
# mean   2023.400000
# std       0.491952
# min    2023.000000
# 25%    2023.000000
# 50%    2023.000000
# 75%    2024.000000
# max    2024.000000

# %%
#To drop redundant observations
print(f"Set size before dropping redundant observations: {df.shape}")
df.drop_duplicates(inplace=True)
print(f"Set size after dropping redundant observations: {df.shape}")
# Out:
# Set size before dropping redundant observations: (120, 8)
# Set size after dropping redundant observations: (120, 8)

# %%
#to create the csv of the modified dataset
df.to_csv('new_cso_data.csv', index=False)

# %%
#To call the function to filter the data by excluding the feature: "All types of accommodation"
df_filtered = load_filter_data('new_cso_data.csv', 'All types of accommodation')

# %%
df_filtered.shape
# Out:
# (100, 8)

# %% [markdown]
# ### Tendency

# %%
# Creates a tendency graphic
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_filtered, x='Month', y='Average Length of Stay of Foreign Visitors (Nights per trip)', hue='Main Accommodation Type', marker='o')
plt.title('Tendency in Average Length of Stay by Accommodation Type')
plt.xlabel('Month')
plt.ylabel('Average Length of Stay (Nights)')
plt.xticks(rotation=45)
plt.legend(title='Accommodation Type')
plt.grid()
plt.show()

# %% [markdown]
# ### Distribution

# %% [markdown]
# Distribution of the key variables in the dataset to identify patterns, trends, and potential outliers that could impact the analysis.

# %%
#To verify the distribution, creates an histogram and a Q-Q plot of Number of overnight trips and Number of nights stayed
feature = 'Number of Overnight Trips by Foreign Visitors (Thousand)'
data = df_filtered[feature].values

#Creates a histogram
plt.figure(figsize=(10, 6))
sns.histplot(data, bins=30, kde=True)
plt.title('Histogram of Number of Overnight Trips by Foreign Visitors')
plt.xlabel(feature)
plt.ylabel('Frecuence')
plt.show()

# Creates a Q-Q Plot
plt.figure(figsize=(10, 6))
stats.probplot(data, dist="norm", plot=plt)
plt.title('Q-Q Plot: Comparing Number of Overnight Trips to Normal Distribution')
plt.show()


feature2 = 'Number of Nights by Foreign Visitors (Thousand)'
data2 = df_filtered[feature2].values

#Creates a histogram
plt.figure(figsize=(10, 6))
sns.histplot(data2, bins=30, kde=True)
plt.title('Histogram of Number of Nights Stayed by Foreign Visitors')
plt.xlabel(feature2)
plt.ylabel('Frecuence')
plt.show()

# Creates a Q-Q Plot
plt.figure(figsize=(10, 6))
stats.probplot(data2, dist="norm", plot=plt)
plt.title('Q-Q Plot: Comparing Number of Nights to Normal Distribution')
plt.show()

feature3 = 'Average Length of Stay of Foreign Visitors (Nights per trip)'
data3 = df_filtered[feature3].values

#Creates a histogram
plt.figure(figsize=(10, 6))
sns.histplot(data3, bins=30, kde=True)
plt.title('Histogram of Average Length of Stay')
plt.xlabel(feature3)
plt.ylabel('Frecuence')
plt.show()

# Creates a Q-Q Plot
plt.figure(figsize=(10, 6))
stats.probplot(data3, dist="norm", plot=plt)
plt.title('Q-Q Plot: Comparing Average Length of Stay to Normal Distribution')
plt.show()

# %%
#To check the skewness of Average Length of Stay
data = np.array(df_filtered['Average Length of Stay of Foreign Visitors (Nights per trip)'])  
#To get the number of observations
n = len(data)

#Calculates the population mean and standar deviation
mean = np.mean(data)
std_dev = np.std(data, ddof=0)  

#To calculate the sample skewness
skewness = (n / ((n - 1) * (n - 2))) * np.sum(((data - mean) / std_dev) ** 3)

print(f"Skewness: {skewness}")
# Out:
# Skewness: 3.2266975233116497

# %%
#To split the dataset into groups by year
by_year = df_filtered.groupby('Year')

#Shapiro-Wilk test by year to get a statistical confirmation of the distribution
shapiro_results_overnights= {}
print('Number of Overnight Trips by Foreign Visitors (Thousand)')
for year, group in by_year:
    stat, p_value= shapiro(group['Number of Overnight Trips by Foreign Visitors (Thousand)'])
    shapiro_results_overnights[year]= {'Statistics': stat, 'p-value': p_value}

#Loop to show results by year
for year, result in shapiro_results_overnights.items():
    print(f"Year: {year}, Shapiro-Wilk Test: Statistics={result['Statistics']}, p-value={result['p-value']}")


shapiro_results_nights= {}
print('\nNumber of Nights by Foreign Visitors (Thousand)')
for year, group in by_year:
    stat, p_value= shapiro(group['Number of Nights by Foreign Visitors (Thousand)'])
    shapiro_results_nights[year]= {'Statistics': stat, 'p-value': p_value}

#Loop to show results by year
for year, result in shapiro_results_nights.items():
    print(f"Year: {year}, Shapiro-Wilk Test: Statistics={result['Statistics']}, p-value={result['p-value']}")


shapiro_results_average= {}
print('\nAverage Length of Stay of Foreign Visitors (Nights per trip)')
for year, group in by_year:
    stat, p_value= shapiro(group['Average Length of Stay of Foreign Visitors (Nights per trip)'])
    shapiro_results_average[year]= {'Statistics': stat, 'p-value': p_value}

#Loop to show results by year
for year, result in shapiro_results_average.items():
    print(f"Year: {year}, Shapiro-Wilk Test: Statistics={result['Statistics']}, p-value={result['p-value']}")
# Out:
# Number of Overnight Trips by Foreign Visitors (Thousand)
# Year: 2023, Shapiro-Wilk Test: Statistics=0.7943445236191108, p-value=9.786312382023767e-08
# Year: 2024, Shapiro-Wilk Test: Statistics=0.8056541346472592, p-value=8.905279815296568e-06
#
# Number of Nights by Foreign Visitors (Thousand)
# Year: 2023, Shapiro-Wilk Test: Statistics=0.8454348148030089, p-value=2.239924805800112e-06
# Year: 2024, Shapiro-Wilk Test: Statistics=0.8703441633009102, p-value=0.00029201577720950787
#
# Average Length of Stay of Foreign Visitors (Nights per trip)
# Year: 2023, Shapiro-Wilk Test: Statistics=0.7231257354096664, p-value=2.5434651333630874e-09
# Year: 2024, Shapiro-Wilk Test: Statistics=0.9371620844034774, p-value=0.027769937188239797

# %% [markdown]
# ### Outlier detection

# %% [markdown]
# Identifying and removing outliers of each feature to ensure the accuracy of the analysis

# %% [markdown]
# #### Identifying outliers

# %%
#Creates a boxplot to visualize outliers
plt.figure(figsize=(20, 12))
sns.boxplot(y='Number of Overnight Trips by Foreign Visitors (Thousand)', data=df_filtered)
plt.title('Boxplot: General distribution of Overnight Trips')
plt.xlabel('General Distribution')
plt.ylabel('Number of Overnight Trips by Foreign Visitors (Thousand)')
plt.show()


#Creates a boxplot for each year to visualize outliers
plt.figure(figsize=(20, 12))
sns.boxplot(x='Year', y='Number of Overnight Trips by Foreign Visitors (Thousand)', data=df_filtered)
plt.title('Boxplot: distribution of Number of Overnight Trips by year')
plt.xlabel('Year')
plt.ylabel('Overnight Trips')
plt.show()

# %%
#Creates a boxplot to visualize outliers
plt.figure(figsize=(20, 12))
sns.boxplot(y='Number of Nights by Foreign Visitors (Thousand)', data=df_filtered)
plt.title('Boxplot: General distribution of Number of Nights')
plt.xlabel('General Distribution')
plt.ylabel('Number of Nights by Foreign Visitors')
plt.show()


#Creates a boxplot for each year to visualize outliers
plt.figure(figsize=(20, 12))
sns.boxplot(x='Year', y='Number of Nights by Foreign Visitors (Thousand)', data=df_filtered)
plt.title('Number of Nights by year Boxplot')
plt.xlabel('Year')
plt.ylabel('Number of Nights by Foreign Visitors (Thousand)')
plt.show()

# %%
#Creates a boxplot to visualize outliers
plt.figure(figsize=(20, 12))
sns.boxplot(y='Average Length of Stay of Foreign Visitors (Nights per trip)', data=df_filtered)
plt.title('Boxplot: General distribution of Average Length of Stay')
plt.xlabel('General Distribution')
plt.ylabel('Average Length of Stay')
plt.show()


#Creates a boxplot for each year to visualize outliers
plt.figure(figsize=(20, 12))
sns.boxplot(x='Year', y='Average Length of Stay of Foreign Visitors (Nights per trip)', data=df_filtered)
plt.title('Boxplot: Average Length of Stay Boxplot by year')
plt.xlabel('Year')
plt.ylabel('Average Length of Stay')
plt.show()

# %%
#To calculate outliers with the function calculate_iqr (for each feature)
outliers = calculate_iqr(df_filtered, 'Number of Overnight Trips by Foreign Visitors (Thousand)')
outliers = calculate_iqr(df_filtered, 'Number of Nights by Foreign Visitors (Thousand)')
outliers = calculate_iqr(df_filtered, 'Average Length of Stay of Foreign Visitors (Nights per trip)')

# %% [markdown]
# #### Removing outliers

# %%
#To delete outliers
df_no_outliers = df_filtered[~df_filtered.index.isin(outliers.index)]

# %% [markdown]
# #### Data with no outliers

# %%
#Creates boxplot with no outliers
plt.figure(figsize=(20, 12))
sns.boxplot(x='Year', y='Average Length of Stay of Foreign Visitors (Nights per trip)', data=df_no_outliers)
plt.title('Average Length of Stay Boxplot (No Outliers)')
plt.xlabel('Year')
plt.ylabel('Average Length of Stay')
plt.show()

# %%
#Creates a boxplot showing the distribution of the number of nights spent by foreign visitors grouped by their main type of accommodation
plt.figure(figsize=(20, 12))
sns.boxplot(x='Main Accommodation Type', y='Number of Nights by Foreign Visitors (Thousand)', data=df_no_outliers)
plt.title('Distribution of the Number of Nights Spent by Accommodation Type')
plt.xlabel('Accommodation Type')
plt.ylabel('Number of Nights Spent (Thousands)')
plt.show()

# %%
#Creates a boxplot showing the distribution of the Average Length of Stay by foreign visitors grouped by their main type of accommodation
plt.figure(figsize=(20, 12))
sns.boxplot(x='Main Accommodation Type', y='Average Length of Stay of Foreign Visitors (Nights per trip)', data=df_no_outliers)
plt.title('Distribution of the Average Length of Stay by Accommodation Type')
plt.xlabel('Accommodation Type')
plt.ylabel('Average Length of Stay (Nights per trip)')
plt.show()

# %%
#Creates a boxplot showing the distribution of the Number of Overnight Trips by foreign visitors grouped by their main type of accommodation
plt.figure(figsize=(20, 12))
sns.boxplot(x='Main Accommodation Type', y='Number of Overnight Trips by Foreign Visitors (Thousand)', data=df_no_outliers)
plt.title('Distribution of the Number of Overnight Trips by Accommodation Type')
plt.xlabel('Accommodation Type')
plt.ylabel('Number of Overnight Trips (Thousand)')
plt.show()

# %%
#To compare the std original and after the quartiles method
#For Average of stay
print('\nAverage Length of Stay of Foreign Visitors')
orig_std3 = df_filtered['Average Length of Stay of Foreign Visitors (Nights per trip)'].std()
processed_std3 =  df_no_outliers['Average Length of Stay of Foreign Visitors (Nights per trip)'].std()

print(f"Original std: {orig_std3}")
print(f"No outliers std: {processed_std3}")
# Out:
# Average Length of Stay of Foreign Visitors
# Original std: 7.213189378499709
# No outliers std: 3.8385623014755788

# %%
#To calculate the average length of stay for each accommodation type
average_accommodation_no_outliers = df_no_outliers.groupby('Main Accommodation Type').mean()

# Display the results
print("Averages without outliers:")
print(average_accommodation_no_outliers[['Average Length of Stay of Foreign Visitors (Nights per trip)']])
# Out:
# Averages without outliers:
#                                             Average Length of Stay of Foreign Visitors (Nights per trip)
# Main Accommodation Type
# Friends/relatives/own property                                                       8.785000
# Guest house/bed & breakfast                                                          6.945000
# Hotel/conference centre                                                              4.570000
# Other private tourism accommodation n.e.c.                                          14.626667
# Self catering/rented house                                                          11.744444

# %% [markdown]
# ## Statistical analysis

# %% [markdown]
# ### Correlation

# %%
#Selecting variables for to correlate on the heatmap 
features = [
    'Average Length of Stay of Foreign Visitors (Nights per trip)',
    'Number of Nights by Foreign Visitors (Thousand)',
    'Number of Overnight Trips by Foreign Visitors (Thousand)',
    'Percentage of Nights by Foreign Visitors (%)',
    'Percentage of Overnight Trips by Foreign Visitors (%)'
]

#To call the function from utilss
plot_correlation_heatmap(df_no_outliers, features, title= 'Correlation Matrix of Foreign Visitor Travel Metrics')

# %%
#To filter for each accommodation type
types_of_accommodation = df_filtered['Main Accommodation Type'].unique()

#Selecting variables for the heatmap
variables = ['Number of Overnight Trips by Foreign Visitors (Thousand)', 
             'Number of Nights by Foreign Visitors (Thousand)', 
             'Average Length of Stay of Foreign Visitors (Nights per trip)']

#Loop to generate heatmaps for each accommodation type
for accommodation_type in types_of_accommodation:
    #To filter the data for the current accommodation type
    accommodation_data = df_filtered[df_filtered['Main Accommodation Type'] == accommodation_type]
    
    #to call the function from utilss
    plot_correlation_heatmap(accommodation_data, variables, title=f'Correlation Matrix for {accommodation_type}')

# %%
#To create a scatter plot for the number of overnight trips and average length of stay
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Number of Overnight Trips by Foreign Visitors (Thousand)', 
                 y='Average Length of Stay of Foreign Visitors (Nights per trip)', 
                 hue='Main Accommodation Type',  # Color by accommodation type
                 data=df_no_outliers)

#to set the labels 
plt.title('Average Length of Stay vs. Number of Overnight Trips by Accommodation Type')
plt.xlabel('Number of Trips (thousands)')
plt.ylabel('Average Length of Stay (nights)')
plt.legend(title='Accommodation Type')

#To show the plot
plt.show()

# %%
#To create a scatter plot for the number of nights and average length of stay
sns.scatterplot(x='Number of Nights by Foreign Visitors (Thousand)', 
                 y='Average Length of Stay of Foreign Visitors (Nights per trip)', 
                 data=df_no_outliers)

#to set the labels 
plt.title('Relationship Between Total Nights and Average Stay Length of Foreign Visitors')
plt.xlabel('Number of Nights (thousands)')
plt.ylabel('Average Length of Stay (nights)')
#to show the plot
plt.show()

# %%
#To divide it by year
years = df_no_outliers['Year'].unique()

#To set up the figure and plots for each year
fig, axes = plt.subplots(1, len(years), figsize=(15, 6), sharey=True)

#Loop to create a plot for eache year
for i, year in enumerate(years):
    sns.scatterplot(x='Number of Overnight Trips by Foreign Visitors (Thousand)', 
                     y='Average Length of Stay of Foreign Visitors (Nights per trip)',
                    #To set different colours for each accommodation type
                     hue='Main Accommodation Type',
                     data=df_no_outliers[df_no_outliers['Year'] == year],
                     ax=axes[i])
    
    # Set labels for each subplot
    axes[i].set_title(f'Average Length of Stay in {year}')
    axes[i].set_xlabel('Number of Trips (thousands)') 
    axes[i].set_ylabel('Average Length of Stay (nights)') 
    axes[i].legend(title='Accommodation Type', bbox_to_anchor=(1.05, 1), loc='upper left')

#To prevent overlap
plt.tight_layout()

#To display the plot
plt.show()

# %%
# Pearson correlation coefficient
pearson_corr = df_no_outliers['Number of Overnight Trips by Foreign Visitors (Thousand)'].corr(df_no_outliers['Average Length of Stay of Foreign Visitors (Nights per trip)'], method='pearson')
print(f"Pearson correlation coefficient: {pearson_corr}")

# Spearman correlation coefficient
spearman_corr = df_no_outliers['Number of Overnight Trips by Foreign Visitors (Thousand)'].corr(df_no_outliers['Average Length of Stay of Foreign Visitors (Nights per trip)'], method='spearman')
print(f"Spearman correlation coefficient: {spearman_corr}")
# Out:
# Pearson correlation coefficient: -0.453482063148771
# Spearman correlation coefficient: -0.34567201463801195

# %% [markdown]
# ### Probability distributions

# %% [markdown]
# #### Binomial distribution

# %%
#To calculate median stay by year and accomodatio type
median_stay_per_year= df_no_outliers.groupby(['Year', 'Main Accommodation Type'])['Average Length of Stay of Foreign Visitors (Nights per trip)'].median().reset_index()
print('Median Length of Stay per Accommodation Type per Year:')
print(median_stay_per_year)
# Out:
# Median Length of Stay per Accommodation Type per Year:
#    Year                     Main Accommodation Type  \
# 0  2023              Friends/relatives/own property
# 1  2023                 Guest house/bed & breakfast
# 2  2023                     Hotel/conference centre
# 3  2023  Other private tourism accommodation n.e.c.
# 4  2023                  Self catering/rented house
# 5  2024              Friends/relatives/own property
# 6  2024                 Guest house/bed & breakfast
# 7  2024                     Hotel/conference centre
# 8  2024  Other private tourism accommodation n.e.c.
# 9  2024                  Self catering/rented house
#
#    Average Length of Stay of Foreign Visitors (Nights per trip)
# 0                                               8.40
# 1                                               6.60
# 2                                               4.65
# 3                                              15.60
# 4                                              11.60
# 5                                               7.95
# 6                                               6.25
# 7                                               4.65
# 8                                              14.50
# 9                                              12.15

# %%
#To create a copy of df_no_outliers to avoid modifying the original DataFrame
df_copy = df_no_outliers.copy()

#Converting to binary based on threshold
df_no_outliers['Long Stay'] = df_no_outliers['Average Length of Stay of Foreign Visitors (Nights per trip)'] > 10

#Number of trials and probability of success (long stay)
n = len(df_no_outliers)
p = df_no_outliers['Long Stay'].mean()
#to set the seed for reproducibility
np.random.seed(33)

#Binomial distribution using numpy
binom_dist = np.random.binomial(n, p, 10000)

# Plot the distribution
plt.hist(binom_dist, bins=30, density=True, alpha=0.6, color='g')
plt.axvline(x=np.mean(binom_dist), color='r', linestyle='dashed', linewidth=2)
plt.text(np.mean(binom_dist) + 2, plt.ylim()[1] * 0.8, f'Mean: {np.mean(binom_dist):.2f}', color='r')
plt.title('Binomial Distribution of Long Stays')
plt.xlabel('Number of Long Stays')
plt.ylabel('Probability Density')
plt.show()
# Out:
# C:\Users\trayd\AppData\Local\Temp\ipykernel_26440\666722374.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_outliers['Long Stay'] = df_no_outliers['Average Length of Stay of Foreign Visitors (Nights per trip)'] > 10

# %% [markdown]
# #### Poisson distribution

# %%
#Calling the poisson distribution function for hotel/conference center
plot_poisson_distribution(df_no_outliers, 'Main Accommodation Type', 'Hotel/conference centre')

# %%
#Calling the function with for Guest house/bed & breakfast
plot_poisson_distribution(df_no_outliers, 'Main Accommodation Type', 'Guest house/bed & breakfast')

# %%
#Calling the function with for Friends/relatives/own property
plot_poisson_distribution(df_no_outliers, 'Main Accommodation Type', 'Friends/relatives/own property')

# %%
#Calling the function with for Self catering/rented house
plot_poisson_distribution(df_no_outliers, 'Main Accommodation Type', 'Self catering/rented house')

# %% [markdown]
# #### Normal distribution

# %%
#Caling the function 
transformed_df = log_transform_dataframe(df_no_outliers, [    'Average Length of Stay of Foreign Visitors (Nights per trip)',
    'Number of Nights by Foreign Visitors (Thousand)',
    'Number of Overnight Trips by Foreign Visitors (Thousand)',
    'Percentage of Nights by Foreign Visitors (%)',
    'Percentage of Overnight Trips by Foreign Visitors (%)'])
print(transformed_df)
# Out:
#     Month                     Main Accommodation Type  \
# 0       1                     Hotel/conference centre
# 1       1                 Guest house/bed & breakfast
# 2       1              Friends/relatives/own property
# 3       1                  Self catering/rented house
# 5       2                     Hotel/conference centre
# ..    ...                                         ...
# 95      8                     Hotel/conference centre
# 96      8                 Guest house/bed & breakfast
# 97      8              Friends/relatives/own property
# 98      8                  Self catering/rented house
# 99      8  Other private tourism accommodation n.e.c.
#
#     Number of Overnight Trips by Foreign Visitors (Thousand)  \
# 0                                               121.0
# 1                                                 8.5
# 2                                               243.4
# 3                                                13.8
# 5                                               142.9
# ..                                                ...
# 95                                              298.6
# 96                                               62.9
# 97                                              290.9
# 98                                               43.3
# 99                                               68.0
#
#     Percentage of Overnight Trips by Foreign Visitors (%)  \
# 0                                                30.3
# 1                                                 2.1
# 2                                                60.8
# 3                                                 3.4
# 5                                                42.4
# ..                                                ...
# 95                                               39.1
# 96                                                8.2
# 97                                               38.1
# 98                                                5.7
# 99                                                8.9
#
#     Number of Nights by Foreign Visitors (Thousand)  \
# 0                                             441.9
# 1                                              55.9
# 2                                            2701.9
# 3                                             154.8
# 5                                             503.1
# ..                                              ...
# 95                                           1743.9
# 96                                            559.3
# 97                                           2958.5
# 98                                            483.7
# 99                                            920.8
#
#     Percentage of Nights by Foreign Visitors (%)  \
# 0                                           12.0
# 1                                            1.5
# 2                                           73.1
# 3                                            4.2
# 5                                           20.6
# ..                                           ...
# 95                                          26.2
# 96                                           8.4
# 97                                          44.4
# 98                                           7.3
# 99                                          13.8
#
#     Average Length of Stay of Foreign Visitors (Nights per trip)  Year  \
# 0                                                 3.7             2023
# 1                                                 6.6             2023
# 2                                                11.1             2023
# 3                                                11.2             2023
# 5                                                 3.5             2023
# ..                                                ...              ...
# 95                                                5.8             2024
# 96                                                8.9             2024
# 97                                               10.2             2024
# 98                                               11.2             2024
# 99                                               13.5             2024
#
#     Long Stay  \
# 0       False
# 1       False
# 2        True
# 3        True
# 5       False
# ..        ...
# 95      False
# 96      False
# 97       True
# 98       True
# 99       True
#
#     log_Average Length of Stay of Foreign Visitors (Nights per trip)  \
# 0                                            1.547563
# 1                                            2.028148
# 2                                            2.493205
# 3                                            2.501436
# 5                                            1.504077
# ..                                                ...
# 95                                           1.916923
# 96                                           2.292535
# 97                                           2.415914
# 98                                           2.501436
# 99                                           2.674149
#
#     log_Number of Nights by Foreign Visitors (Thousand)  \
# 0                                            6.093344
# 1                                            4.041295
# 2                                            7.902081
# 3                                            5.048573
# 5                                            6.222775
# ..                                                ...
# 95                                           7.464453
# 96                                           6.328472
# 97                                           7.992776
# 98                                           6.183530
# 99                                           6.826328
#
#     log_Number of Overnight Trips by Foreign Visitors (Thousand)  \
# 0                                            4.804021
# 1                                            2.251292
# 2                                            5.498806
# 3                                            2.694627
# 5                                            4.969119
# ..                                                ...
# 95                                           5.702448
# 96                                           4.157319
# 97                                           5.676411
# 98                                           3.790985
# 99                                           4.234107
#
#     log_Percentage of Nights by Foreign Visitors (%)  \
# 0                                           2.564949
# 1                                           0.916291
# 2                                           4.305416
# 3                                           1.648659
# 5                                           3.072693
# ..                                               ...
# 95                                          3.303217
# 96                                          2.240710
# 97                                          3.815512
# 98                                          2.116256
# 99                                          2.694627
#
#     log_Percentage of Overnight Trips by Foreign Visitors (%)
# 0                                            3.443618
# 1                                            1.131402
# 2                                            4.123903
# 3                                            1.481605
# 5                                            3.770459
# ..                                                ...
# 95                                           3.691376
# 96                                           2.219203
# 97                                           3.666122
# 98                                           1.902108
# 99                                           2.292535
#
# [93 rows x 14 columns]

# %%
#To check the skewness of Average Length of Stay
data = np.array(transformed_df['Average Length of Stay of Foreign Visitors (Nights per trip)'])  
#To get the number of observations
n = len(data)

#Calculates the population mean and standar deviation
mean = np.mean(data)
std_dev = np.std(data, ddof=0)  

#To calculate the sample skewness
skewness = (n / ((n - 1) * (n - 2))) * np.sum(((data - mean) / std_dev) ** 3)

print(f"Skewness: {skewness}")
# Out:
# Skewness: 0.5941301420852065
